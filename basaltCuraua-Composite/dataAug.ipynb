# %%
import pandas as pd

# %%
df = pd.read_csv("compositeData.csv")
df
# Out:
#     fibre_length  basalt_fiber_content  curaua_fiber_content  tensile_strength
# 0              4                   100                     0             50.38
# 1              4                   100                     0             30.36
# 2              4                    75                    25             25.24
# 3              4                    75                    25             27.22
# 4              4                    75                    25             23.01
# 5              4                    50                    50             23.71
# 6              4                    50                    50             26.87
# 7              4                    50                    50             22.89
# 8              4                    25                    75             32.67
# 9              4                    25                    75             32.11
# 10             4                    25                    75             29.97
# ...

# %%
augDf = pd.concat([df,pd.concat([df,df])])
augDf
# Out:
#     fibre_length  basalt_fiber_content  curaua_fiber_content  tensile_strength
# 0              4                   100                     0             50.38
# 1              4                   100                     0             30.36
# 2              4                    75                    25             25.24
# 3              4                    75                    25             27.22
# 4              4                    75                    25             23.01
# ..           ...                   ...                   ...               ...
# 40            12                    25                    75             21.15
# 41            12                     0                   100             33.67
# 42            12                     0                   100             36.83
# 43            12                     0                   100             34.40
# 44            12                     0                   100             36.36
#
# [135 rows x 4 columns]

# %%
augmentedDf = augDf.sample(frac=1).reset_index(drop=True)
augmentedDf
# Out:
#      fibre_length  basalt_fiber_content  curaua_fiber_content  \
# 0               4                    25                    75
# 1              12                    50                    50
# 2               4                   100                     0
# 3               4                    25                    75
# 4               8                    75                    25
# ..            ...                   ...                   ...
# 130             8                    25                    75
# 131             4                     0                   100
# 132             8                    75                    25
# 133             8                    50                    50
# 134             4                    75                    25
#
#      tensile_strength
# 0               32.11
# 1               25.65
# 2               50.38
# 3               32.67
# 4               39.14
# ..                ...
# 130             27.98
# 131             17.20
# ...
